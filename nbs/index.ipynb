# %%
#| hide
from Text2SQL.core import *

# %% [markdown]
# # Text2SQL
#
# > for text 2 sql

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install Text2SQL in Development mode

# %% [markdown]
# ```sh
# # make sure Text2SQL package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to Text2SQL
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/tripathysagar/Text2SQL.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c tripathysagar Text2SQL
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install Text2SQL
# ```
#
#
# [repo]: https://github.com/tripathysagar/Text2SQL
# [docs]: https://tripathysagar.github.io/Text2SQL/
# [pypi]: https://pypi.org/project/Text2SQL/
# [conda]: https://anaconda.org/tripathysagar/Text2SQL

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/tripathysagar/Text2SQL
# [docs]: https://tripathysagar.github.io/Text2SQL/
# [pypi]: https://pypi.org/project/Text2SQL/
# [conda]: https://anaconda.org/tripathysagar/Text2SQL

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
